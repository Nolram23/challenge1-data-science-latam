# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
sum1 = tienda['Precio'].sum()
sum2 = tienda2['Precio'].sum()
sum3 = tienda3['Precio'].sum()
sum4 = tienda4['Precio'].sum()
print(sum1)
print(sum2)
print(sum3)
print(sum4)
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0

# %%
suma_precios = {
    'Tienda 1': tienda['Precio'].sum(),
    'Tienda 2': tienda2['Precio'].sum(),
    'Tienda 3': tienda3['Precio'].sum(),
    'Tienda 4': tienda4['Precio'].sum(),
}

for tienda, suma in suma_precios.items():
    print(f"{tienda}: ${suma:,.2f}")
# Out:
# Tienda 1: $1,150,880,400.00
# Tienda 2: $1,116,343,500.00
# Tienda 3: $1,098,019,600.00
# Tienda 4: $1,038,375,700.00

# %%
cantidad_categorias = {
    'Tienda 1': tienda['Categoría del Producto'].nunique(),
    'Tienda 2': tienda2['Categoría del Producto'].nunique(),
    'Tienda 3': tienda3['Categoría del Producto'].nunique(),
    'Tienda 4': tienda4['Categoría del Producto'].nunique(),
}

for tienda, cantidad in cantidad_categorias.items():
    print(f"{tienda}: {cantidad} categorías únicas")
# Out:
# Tienda 1: 8 categorías únicas
# Tienda 2: 8 categorías únicas
# Tienda 3: 8 categorías únicas
# Tienda 4: 8 categorías únicas

# %%
# Contar cuántos productos hay por categoría
conteo_categorias = tienda['Categoría del Producto'].value_counts()
conteo_categorias2 = tienda2['Categoría del Producto'].value_counts()
conteo_categorias3 = tienda3['Categoría del Producto'].value_counts()
conteo_categorias4 = tienda4['Categoría del Producto'].value_counts()

# Unirlos en un solo DataFrame
conteo_total = pd.concat(
    [conteo_categorias, conteo_categorias2, conteo_categorias3, conteo_categorias4],
    axis=1
)

# Renombrar las columnas para identificar cada tienda
conteo_total.columns = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Llenar valores faltantes con 0 (por si alguna tienda no tiene una categoría)
conteo_total = conteo_total.fillna(0).astype(int)

# Mostrar como tabla
print("Cantidad de ítems por categoría y tienda:\n")
print(conteo_total)
# Out:
# Cantidad de ítems por categoría y tienda:
#
#                          Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Categoría del Producto
# Muebles                       465       442       499       480
# Electrónicos                  448       422       451       451
# Juguetes                      324       313       315       338
# Electrodomésticos             312       305       278       254
# Deportes y diversión          284       275       277       277
# Instrumentos musicales        182       224       177       170
# Libros                        173       197       185       187
# Artículos para el hogar       171       181       177       201

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Lista de las tiendas
tiendas = [tienda, tienda2, tienda3, tienda4]

# Recorrer cada tienda y mostrar el conteo
for i, tienda in enumerate(tiendas, start=1):
    print(f"\nTienda {i}:")
    conteo = tienda['Categoría del Producto'].value_counts()
    for categoria, cantidad in conteo.items():
        print(f"- {categoria}: {cantidad} ítems")
# Out:
# Tienda 1:
# - Muebles: 480 ítems
# - Electrónicos: 451 ítems
# - Juguetes: 338 ítems
# - Deportes y diversión: 277 ítems
# - Electrodomésticos: 254 ítems
# - Artículos para el hogar: 201 ítems
# - Libros: 187 ítems
# - Instrumentos musicales: 170 ítems
#
# Tienda 2:
# - Muebles: 442 ítems
# - Electrónicos: 422 ítems
# - Juguetes: 313 ítems
# - Electrodomésticos: 305 ítems
# - Deportes y diversión: 275 ítems
# - Instrumentos musicales: 224 ítems
# - Libros: 197 ítems
# - Artículos para el hogar: 181 ítems
#
# Tienda 3:
# - Muebles: 499 ítems
# - Electrónicos: 451 ítems
# - Juguetes: 315 ítems
# - Electrodomésticos: 278 ítems
# - Deportes y diversión: 277 ítems
# - Libros: 185 ítems
# - Instrumentos musicales: 177 ítems
# - Artículos para el hogar: 177 ítems
#
# Tienda 4:
# - Muebles: 480 ítems
# - Electrónicos: 451 ítems
# - Juguetes: 338 ítems
# - Deportes y diversión: 277 ítems
# - Electrodomésticos: 254 ítems
# - Artículos para el hogar: 201 ítems
# - Libros: 187 ítems
# ...

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]

# Crear un diccionario para almacenar los resultados
tabla_conteo = {}

# Recorremos las tiendas
for i, tienda in enumerate(tiendas, start=1):
    conteo = tienda['Categoría del Producto'].value_counts()
    tabla_conteo[f'Tienda {i}'] = conteo

# Convertimos el diccionario en un DataFrame, uniendo por índice (categorías)
resultado = pd.DataFrame(tabla_conteo).fillna(0).astype(int)

# Mostrar la tabla final
print(resultado)
# Out:
#                          Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Categoría del Producto
# Artículos para el hogar       201       181       177       201
# Deportes y diversión          277       275       277       277
# Electrodomésticos             254       305       278       254
# Electrónicos                  451       422       451       451
# Instrumentos musicales        170       224       177       170
# Juguetes                      338       313       315       338
# Libros                        187       197       185       187
# Muebles                       480       442       499       480

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Lista de las tiendas
tiendas = [tienda, tienda2, tienda3, tienda4]

# Crear un diccionario para almacenar los promedios
promedios = {}

# Calcular promedio de calificación por tienda
for i, tienda in enumerate(tiendas, start=1):
    promedio = tienda['Calificación'].mean()
    promedios[f'Tienda {i}'] = round(promedio, 2)  # redondeamos a 2 decimales

# Mostrar el resultado
for tienda, promedio in promedios.items():
    print(f"{tienda}: {promedio} estrellas")
# Out:
# Tienda 1: 4.0 estrellas
# Tienda 2: 4.04 estrellas
# Tienda 3: 4.05 estrellas
# Tienda 4: 4.0 estrellas

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Lista de las tiendas
tiendas = [tienda, tienda2, tienda3, tienda4]

# Procesar cada tienda
for i, tienda in enumerate(tiendas, start=1):
    print(f"\nTienda {i}:")

    # Contar las veces que aparece cada producto
    conteo = tienda['Producto'].value_counts()

    # Producto más vendido (mayor conteo)
    producto_mas_vendido = conteo.idxmax()
    ventas_mas = conteo.max()

    # Producto menos vendido (menor conteo)
    producto_menos_vendido = conteo.idxmin()
    ventas_menos = conteo.min()

    print(f"Producto más vendido: {producto_mas_vendido} ({ventas_mas} ventas)")
    print(f"Producto menos vendido: {producto_menos_vendido} ({ventas_menos} ventas)")
# Out:
# Tienda 1:
# Producto más vendido: Cama box (62 ventas)
# Producto menos vendido: Guitarra eléctrica (33 ventas)
#
# Tienda 2:
# Producto más vendido: Iniciando en programación (65 ventas)
# Producto menos vendido: Juego de mesa (32 ventas)
#
# Tienda 3:
# Producto más vendido: Kit de bancas (57 ventas)
# Producto menos vendido: Bloques de construcción (35 ventas)
#
# Tienda 4:
# Producto más vendido: Cama box (62 ventas)
# Producto menos vendido: Guitarra eléctrica (33 ventas)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import matplotlib.pyplot as plt

# Lista de nombres de las tiendas
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Lista de dataframes de las tiendas
tiendas = [tienda, tienda2, tienda3, tienda4]

# Calcular promedios de costo de envío
promedios_envio = [t['Costo de envío'].mean() for t in tiendas]

# %%
conteo_total.plot(kind='bar')
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %%
conteo_total.T.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
conteo_total.plot(kind='line')
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %%
tienda['Categoría del Producto'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(conteo_total, annot=True, fmt='g', cmap="YlGnBu")
plt.title("Cantidad de ítems por Categoría y Tienda")
plt.ylabel("Categoría del Producto")
plt.xlabel("Tienda")
plt.show()

# %%
# graficar promedios:
# Graficar
plt.figure(figsize=(8, 5))
plt.bar(nombres_tiendas, promedios_envio, color='skyblue')
plt.ylabel('Costo de Envío Promedio ($)')
plt.title('Costo de Envío Promedio por Tienda')

# Mostrar etiquetas encima de cada barra
for i, promedio in enumerate(promedios_envio):
    plt.text(i, promedio + 0.1, f"${promedio:,.2f}", ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Lista de nombres de las tiendas
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Lista de dataframes de las tiendas
tiendas = [tienda, tienda2, tienda3, tienda4]

# Calcular promedios
promedios_envio = [t['Costo de envío'].mean() for t in tiendas]
promedios_calificacion = [t['Calificación'].mean() for t in tiendas]

# Configurar posiciones para las barras agrupadas
x = np.arange(len(nombres_tiendas))
ancho = 0.35  # Ancho de las barras

# Crear gráfico
plt.figure(figsize=(10, 6))
barras1 = plt.bar(x - ancho/2, promedios_envio, width=ancho, label='Costo de Envío Promedio ($)', color='skyblue')
barras2 = plt.bar(x + ancho/2, promedios_calificacion, width=ancho, label='Promedio de Calificación', color='lightgreen')

# Etiquetas y leyenda
plt.ylabel('Promedio')
plt.title('Comparación: Costo de Envío vs Calificación por Tienda')
plt.xticks(x, nombres_tiendas)
plt.legend()

# Mostrar valores encima de las barras
for barra in barras1:
    plt.text(barra.get_x() + barra.get_width() / 2, barra.get_height() + 0.05, f"${barra.get_height():.2f}", ha='center')
for barra in barras2:
    plt.text(barra.get_x() + barra.get_width() / 2, barra.get_height() + 0.05, f"{barra.get_height():.2f}", ha='center')

plt.tight_layout()
plt.show()
